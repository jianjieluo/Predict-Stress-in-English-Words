# %% [markdown]
# # Visualization of some model we choose.

# %% [markdown]
# Use this notebook to generate some model picture we choose.

# %%
import helper
from submission import *
import numpy as np
from sklearn.cross_validation import train_test_split 
from sklearn.metrics import f1_score
from sklearn import tree
import pydotplus

# %%
# read the raw data
raw_data = helper.read_data('./asset/training_data.txt')
features, labels = training_preprocess(raw_data)
# Out:
# /home/longj/anaconda3/envs/py36/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
clf_dtree_entropy = tree.DecisionTreeClassifier(criterion='entropy', max_depth=5)
clf_dtree_entropy.fit(features, labels)

dot_data = tree.export_graphviz(clf_dtree_entropy, out_file=None) 
graph = pydotplus.graph_from_dot_data(dot_data) 
graph.write_pdf("./asset/entropy_decisiontree_m5.pdf")
# Out:
# True

# %%
from IPython.display import Image
feature_names = ['vowel_seq1', 'vowel_seq2', 'vowel_seq3',
'vowel_seq4', 'comb_seq1', 'comb_seq2', 'comb_seq3', 'comb_seq4','vowels_count', 'has_pre']
target_names = ['0', '1', '2', '3', '4']

dot_data = tree.export_graphviz(clf_dtree_entropy, out_file=None, 
                 feature_names=feature_names,  
                 class_names=target_names,  
                 filled=True, rounded=True,  
                 special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
clf_dtree_entropy = tree.DecisionTreeClassifier(criterion='entropy', max_depth=6)
clf_dtree_entropy.fit(features, labels)

dot_data = tree.export_graphviz(clf_dtree_entropy, out_file=None) 
graph = pydotplus.graph_from_dot_data(dot_data) 
graph.write_pdf("./asset/entropy_decisiontree_m6.pdf")
# Out:
# True

# %%
dot_data = tree.export_graphviz(clf_dtree_entropy, out_file=None, 
                 feature_names=feature_names,  
                 class_names=target_names,  
                 filled=True, rounded=True,  
                 special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
